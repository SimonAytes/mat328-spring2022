# %% [markdown]
# # Lab 1: MAT 128 Review
#
# This lab reviews the most important data manipulation, filtering, and plotting techniques from MAT 128:
#
# * data frames
# * loading CSV files, including data columns
# * missing data
# * mean, median, and standard deviation of a column
# * line plots
# * accessing date information
# * histogram
# * creating new columns from existing ones
# * bar charts
# * filtering
#
# We explore the New York City weather data from 2014 and 2015.  This data was curated by [FiveThirtyEight.com](fivethirtyeight.com) and used in their article [What 12 Months of Record-Setting Temperatures Looks Like Across the U.S.](https://fivethirtyeight.com/features/what-12-months-of-record-setting-temperatures-looks-like-across-the-u-s/).
#
# ### Section 1.1: Loading the data
#
# First import the necessary *libraries* (also called *modules* or *packages*):
# * [pandas](https://pandas.pydata.org/): data analysis tools
# * [matplotlib](https://matplotlib.org/): plotting
# * [seaborn](https://seaborn.pydata.org/):  higher-level data visualization built on the MatPlotLib library

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# The following line is needed for some versions of Python and Jupyter Notebooks to display the plots in the notebook.
# %matplotlib inline

# %% [markdown]
# We will now read the data file, which is in *Comma-Separated Values (CSV)* format, into a *DataFrame*.
#
# Recall that a CSV file is a text file that stores the rows of a table (ex. an Excel table) by separating data values in different columns with commas.
#
# A *DataFrame* is how the pandas library (and hence Python) stores a table of data in the computer.
#
# We can load the CSV file from a URL into the DataFrame `weather`:

# %%
weather = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/us-weather-history/KNYC.csv")
weather
# Out:
#           date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0     2014-7-1                81               72               89
# 1     2014-7-2                82               72               91
# 2     2014-7-3                78               69               87
# 3     2014-7-4                70               65               74
# 4     2014-7-5                72               63               81
# ..         ...               ...              ...              ...
# 360  2015-6-26                75               69               81
# 361  2015-6-27                65               58               71
# 362  2015-6-28                68               62               73
# 363  2015-6-29                70               63               76
# 364  2015-6-30                75               68               82
#
#      average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                  68                83               52              100
# 1                  68                83               56              100
# 2                  68                83               54              103
# 3                  68                84               55              102
# 4                  68                84               53              101
# ..                ...               ...              ...              ...
# 360                67                82               56              100
# 361                67                82               55              101
# 362                67                83               54               96
# 363                67                83               52              101
# 364                67                83               53               99
#
#      record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                    1943                  1901                  0.00
# 1                    2001                  1966                  0.96
# 2                    1933                  1966                  1.78
# 3                    1986                  1949                  0.14
# 4                    1979                  1999                  0.00
# ..                    ...                   ...                   ...
# 360                  1979                  1952                  0.00
# 361                  1940                  1966                  1.12
# 362                  1995                  1991                  0.29
# 363                  1919                  1934                  0.00
# 364                  1919                  1964                  0.00
#
#      average_precipitation  record_precipitation
# 0                     0.12                  2.17
# 1                     0.13                  1.79
# 2                     0.12                  2.80
# 3                     0.13                  1.76
# 4                     0.12                  3.07
# ..                     ...                   ...
# 360                   0.13                  4.29
# 361                   0.12                  2.11
# 362                   0.13                  1.69
# 363                   0.12                  2.57
# 364                   0.13                  3.07
#
# [365 rows x 13 columns]

# %% [markdown]
# Or if you have the file in the same directly as this notebook (hard to do on Colab), you can load the CSV file into the DataFrame `weather` as we did in MAT 128:

# %%
weather = pd.read_csv("KNYC.csv")
weather
# Out:
#           date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0     2014-7-1                81               72               89
# 1     2014-7-2                82               72               91
# 2     2014-7-3                78               69               87
# 3     2014-7-4                70               65               74
# 4     2014-7-5                72               63               81
# ..         ...               ...              ...              ...
# 360  2015-6-26                75               69               81
# 361  2015-6-27                65               58               71
# 362  2015-6-28                68               62               73
# 363  2015-6-29                70               63               76
# 364  2015-6-30                75               68               82
#
#      average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                  68                83               52              100
# 1                  68                83               56              100
# 2                  68                83               54              103
# 3                  68                84               55              102
# 4                  68                84               53              101
# ..                ...               ...              ...              ...
# 360                67                82               56              100
# 361                67                82               55              101
# 362                67                83               54               96
# 363                67                83               52              101
# 364                67                83               53               99
#
#      record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                    1943                  1901                  0.00
# 1                    2001                  1966                  0.96
# 2                    1933                  1966                  1.78
# 3                    1986                  1949                  0.14
# 4                    1979                  1999                  0.00
# ..                    ...                   ...                   ...
# 360                  1979                  1952                  0.00
# 361                  1940                  1966                  1.12
# 362                  1995                  1991                  0.29
# 363                  1919                  1934                  0.00
# 364                  1919                  1964                  0.00
#
#      average_precipitation  record_precipitation
# 0                     0.12                  2.17
# 1                     0.13                  1.79
# 2                     0.12                  2.80
# 3                     0.13                  1.76
# 4                     0.12                  3.07
# ..                     ...                   ...
# 360                   0.13                  4.29
# 361                   0.12                  2.11
# 362                   0.13                  1.69
# 363                   0.12                  2.57
# 364                   0.13                  3.07
#
# [365 rows x 13 columns]

# %% [markdown]
# Look at the DataFrame to answer the following questions:
# * When does the data begin?  **July 1st, 2014**
# * When does it end?   **June 30th, 2015**
# * What kinds of information do we have about the weather? **Statistics regarding the temperature (both on the day and in reference to the year, records, etc.) and general information about the precipitation.**
#
# In the data column names, "actual" refers to the temperature or precipitation (in inches) value recorded on that date, "average" is the historical average value for that day, and "record" is the highest or lowest recorded value for that day.
#
# To only display the first 5 rows of the DataFrame:

# %%
weather.head()
# Out:
#        date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0  2014-7-1                81               72               89
# 1  2014-7-2                82               72               91
# 2  2014-7-3                78               69               87
# 3  2014-7-4                70               65               74
# 4  2014-7-5                72               63               81
#
#    average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                68                83               52              100
# 1                68                83               56              100
# 2                68                83               54              103
# 3                68                84               55              102
# 4                68                84               53              101
#
#    record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                  1943                  1901                  0.00
# 1                  2001                  1966                  0.96
# 2                  1933                  1966                  1.78
# 3                  1986                  1949                  0.14
# 4                  1979                  1999                  0.00
#
#    average_precipitation  record_precipitation
# 0                   0.12                  2.17
# 1                   0.13                  1.79
# 2                   0.12                  2.80
# 3                   0.13                  1.76
# 4                   0.12                  3.07

# %% [markdown]
# ### Section 1.2 Dates
# While we can see that the `date` column is a date, it is not explicitly stored in the DataFrame as a data, and thus we can't use commands for dates on it.
#
# The following code shows the *data type* of each column, which is how the data is stored in Python.

# %%
weather.dtypes
# Out:
# date                      object
# actual_mean_temp           int64
# actual_min_temp            int64
# actual_max_temp            int64
# average_min_temp           int64
# average_max_temp           int64
# record_min_temp            int64
# record_max_temp            int64
# record_min_temp_year       int64
# record_max_temp_year       int64
# actual_precipitation     float64
# average_precipitation    float64
# record_precipitation     float64
# dtype: object

# %% [markdown]
# The following code tells Python to encode the `date` column as a DateTime object, and then displays the updated DataFrame.

# %%
weather["date"] = pd.to_datetime(weather["date"])
weather.head()
# Out:
#         date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0 2014-07-01                81               72               89
# 1 2014-07-02                82               72               91
# 2 2014-07-03                78               69               87
# 3 2014-07-04                70               65               74
# 4 2014-07-05                72               63               81
#
#    average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                68                83               52              100
# 1                68                83               56              100
# 2                68                83               54              103
# 3                68                84               55              102
# 4                68                84               53              101
#
#    record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                  1943                  1901                  0.00
# 1                  2001                  1966                  0.96
# 2                  1933                  1966                  1.78
# 3                  1986                  1949                  0.14
# 4                  1979                  1999                  0.00
#
#    average_precipitation  record_precipitation
# 0                   0.12                  2.17
# 1                   0.13                  1.79
# 2                   0.12                  2.80
# 3                   0.13                  1.76
# 4                   0.12                  3.07

# %% [markdown]
# Do you notice any difference in the `date` column compared to the original DataFrame? **The date format has changed to long-form abbreviations (eg. 7 becomes 07).**
#
# Display the data types of each column again.

# %%
weather.dtypes
# Out:
# date                     datetime64[ns]
# actual_mean_temp                  int64
# actual_min_temp                   int64
# actual_max_temp                   int64
# average_min_temp                  int64
# average_max_temp                  int64
# record_min_temp                   int64
# record_max_temp                   int64
# record_min_temp_year              int64
# record_max_temp_year              int64
# actual_precipitation            float64
# average_precipitation           float64
# record_precipitation            float64
# dtype: object

# %% [markdown]
# How have the data types changed? **`date` has become a column of type `datetime64` instead of `object`.**
#
# ### Section 1.3 Missing data and column statistics
#
# It looks like we have a year's worth of weather data from July 1, 2014 to June 30, 2015.  See if there is any missing data.

# %%
weather.describe()
# Out:
#        actual_mean_temp  actual_min_temp  actual_max_temp  average_min_temp  \
# count        365.000000       365.000000       365.000000        365.000000
# mean          54.736986        47.246575        61.734247         48.016438
# std           18.679979        18.277156        19.446971         14.749176
# min           11.000000         2.000000        19.000000         27.000000
# 25%           39.000000        34.000000        44.000000         34.000000
# 50%           58.000000        50.000000        65.000000         48.000000
# 75%           72.000000        64.000000        80.000000         63.000000
# max           85.000000        77.000000        92.000000         69.000000
#
#        average_max_temp  record_min_temp  record_max_temp  \
# count        365.000000       365.000000       365.000000
# mean          62.079452        28.243836        83.731507
# std           16.068765        20.729107        13.351306
# min           38.000000       -15.000000        54.000000
# 25%           47.000000         8.000000        71.000000
# 50%           63.000000        31.000000        87.000000
# 75%           78.000000        47.000000        96.000000
# max           84.000000        59.000000       106.000000
#
#        record_min_temp_year  record_max_temp_year  actual_precipitation  \
# count            365.000000            365.000000            365.000000
# mean            1924.079452           1958.923288              0.126164
# std               38.000820             34.824357              0.325577
# min             1871.000000           1876.000000              0.000000
# 25%             1888.000000           1933.000000              0.000000
# 50%             1920.000000           1962.000000              0.000000
# 75%             1954.000000           1990.000000              0.050000
# max             2015.000000           2013.000000              2.540000
#
#        average_precipitation  record_precipitation
# count             365.000000            365.000000
# mean                0.136822              2.386137
# std                 0.015734              1.045702
# min                 0.100000              0.860000
# 25%                 0.130000              1.690000
# 50%                 0.140000              2.160000
# 75%                 0.150000              2.750000
# max                 0.170000              8.280000

# %% [markdown]
# The `count` row tells us how many values are in each column.  Since the count is 365 for each column, and this is the number of rows in our DataFrame, then we know there is no missing data.
#
# The `describe()` function also displays the 5-number summary (minimum data value, 25 percentile, 50 percentile or *median*, 75 percentile, and maximum data value) for each numerical column, as well as the mean and standard deviation.
#
# What is the standard deviation of the average minimum temperature? **14.749176**
#
# What is the median actual precipitation? **0.000000**
#
# What is the 75th percentile of record maximum temperature? **80.000000**
#
# ### Section 1.4 Line Plots
#
# Recall that a line plot shows how some data value changes over time.  The following code creates a line plot of the daily mean temperature.

# %%
weather.plot(x = "date", y= "actual_mean_temp")
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# What trends do you notice in the above plot?  Does this make sense? **One apparent trend is the decrease in `actual_mean_temp` during the winter months. This does make sense as it implies seasonality in the temperature, which does exist.**
#
# Remember, our plots should always have a title and axis labels.

# %%
weather.plot(x = "date", y= "actual_mean_temp",legend = False)
plt.title("Daily mean temperature")
plt.xlabel("Date")
plt.ylabel('Mean temperature (F)')
# Out:
# Text(0, 0.5, 'Mean temperature (F)')

# %% [markdown]
# Make a line plot of the daily precipitation, including axes labels and a title.

# %%
weather.plot(x = "date", y= "actual_precipitation",legend = False)
plt.title("Daily precipitation")
plt.xlabel("Date")
plt.ylabel('Daily Precipitation (inches)')
# Out:
# Text(0, 0.5, 'Daily Precipitation (inches)')

# %% [markdown]
# What trends do you notice in your plot?  How does this compare with the plot of the mean daily temperature? **The times of peak precipitation appear to occur during the winter months (specifically November - February). During this same time period, the daily temperature reaches its lowest points, potentially indicating a negative linear correlation between temperature and precipitation.**
#
# Do you think a line plot is the best way to understand the daily precipiation? **No, a histogram grouped by month (or week) would be best for this type of data.**
#
# ### Section 1.5 Histograms
#
# Let's look at another way to visualize the daily precipitation data: plotting the distribution of the daily precipitation.  Recall that since the precipitation data is quantitative, we do this with a histogram.

# %%
weather["actual_precipitation"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Sometimes it is helpful to have a finer breakdown of histogram bins.  Do this by adding the *parameter* `bins = 20` in between the parentheses of the function `hist()` like this:
# `weather["actual_precipitation"].hist(bins = 20)`
#
# A parameter gives a function additional information.
#
# Add a title and axes labels to your plot.

# %%
weather['actual_precipitation'].hist(bins=20)
plt.title("Actual precipitation")
plt.xlabel("Date")
plt.ylabel('Actual Precipitation (inches)')
# Out:
# Text(0, 0.5, 'Actual Precipitation (inches)')

# %% [markdown]
# What do you notice about the daily precipitation distribution?  Is this an approximately normal distribution?  Why or why not? **This distribution appears positively skewed, therefore it is not a normal distribution.**
#
# ### Section 1.6 Creating new columns and bar charts
#
# Maybe it would be helpful to make a bar chart of the number of days with 0 precipitation and the number of days with >0 precipitation.  To do this, we will first make a new column in our DataFrame that contains a 1 if there was precipitation that day, and a 0 if there was not.
#
# Define a function that outputs (returns) 1 if the input value is greater than 0, and 0 if it is not.

# %%
def is_positive(x):
    if x > 0:
        return 1
    else:
        return 0

# %% [markdown]
# Now we use the `apply()` function to pass the value from each row of the `actual_precipitation` column into our `is_positive()` function, and store the output for that row in a new column called `precipitated`.

# %%
weather["precipitated"] = weather["actual_precipitation"].apply(is_positive)

# %% [markdown]
# Display the `weather` DataFrame again to see what happened.

# %%
weather.head()
# Out:
#         date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0 2014-07-01                81               72               89
# 1 2014-07-02                82               72               91
# 2 2014-07-03                78               69               87
# 3 2014-07-04                70               65               74
# 4 2014-07-05                72               63               81
#
#    average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                68                83               52              100
# 1                68                83               56              100
# 2                68                83               54              103
# 3                68                84               55              102
# 4                68                84               53              101
#
#    record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                  1943                  1901                  0.00
# 1                  2001                  1966                  0.96
# 2                  1933                  1966                  1.78
# 3                  1986                  1949                  0.14
# 4                  1979                  1999                  0.00
#
#    average_precipitation  record_precipitation  precipitated
# 0                   0.12                  2.17             0
# 1                   0.13                  1.79             1
# 2                   0.12                  2.80             1
# 3                   0.13                  1.76             1
# 4                   0.12                  3.07             0

# %% [markdown]
# Is this what you expected? **Yes. It added the specified column with accurate values.**
#
# Now let's make a bar chart of the `precipitated` column.  Remember we must compute the value counts first when making a bar chart.

# %%
precip_counts = weather["precipitated"].value_counts()
precip_counts.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Were there more days with or without precipitation?  Is this what you would expect? **There were more days without precipitation. I was expecting more days with precipitation, so it was not what I was expecting.**
#
# Add axes labels and a title to the bar chart.

# %%
precip_counts = weather["precipitated"].value_counts()
precip_counts.plot(kind = "bar")
plt.title("Number of days with precipitation")
plt.xlabel("Breakdown of days with/without precipitation")
plt.ylabel("Number of days")
# Out:
# Text(0, 0.5, 'Number of days')

# %% [markdown]
# Instead of precipitation, we might be interested in the number of hot (or cold) days.  Create a bar chart showing the number of days with a max temperature greater than 80F and the number of days with a max temperature of 80F or less.
#
# (Alternatively, choose your own temperature cut-off.)

# %%
def is_hot(x):
    if x > 80:
        return 1
    else:
        return 0

# %%
weather["is_hot"] = weather["actual_max_temp"].apply(is_hot)

# %%
precip_counts = weather["is_hot"].value_counts()
precip_counts.plot(kind = "bar")
plt.title("Number of hot days")
plt.xlabel("Breakdown of hot and cool days")
plt.ylabel("Number of days")
# Out:
# Text(0, 0.5, 'Number of days')

# %% [markdown]
# ### Section 1.7 Filtering
#
# What about if we only want to look at part of our data, such as the month of February?  Then we need to *filter* our dataset.
#
# Let's plot the distribution of daily minimum temperatures in February.
#
# First we need to filter our data to only includes rows from February.  Recall that we can access just the month part of the date by adding `.dt.month` to the `date` column.

# %%
feb_filter = weather["date"].dt.month == 2
weather[feb_filter]
# Out:
#           date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 215 2015-02-01                28               20               36
# 216 2015-02-02                24               14               34
# 217 2015-02-03                20               13               26
# 218 2015-02-04                34               24               43
# 219 2015-02-05                28               14               42
# 220 2015-02-06                20               12               27
# 221 2015-02-07                33               25               40
# 222 2015-02-08                33               29               37
# 223 2015-02-09                27               25               29
# 224 2015-02-10                33               26               40
# 225 2015-02-11                28               22               34
# 226 2015-02-12                28               16               40
# 227 2015-02-13                15                8               21
# 228 2015-02-14                24               16               32
# 229 2015-02-15                15                4               25
# 230 2015-02-16                12                3               21
# 231 2015-02-17                21               14               27
# 232 2015-02-18                26               19               33
# 233 2015-02-19                18                8               27
# 234 2015-02-20                11                2               19
# 235 2015-02-21                23               13               32
# 236 2015-02-22                38               32               43
# 237 2015-02-23                23                8               38
# 238 2015-02-24                14                4               24
# 239 2015-02-25                29               20               37
# 240 2015-02-26                27               21               32
# 241 2015-02-27                24               18               30
# 242 2015-02-28                21               13               29
#
#      average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 215                27                39               -2               67
# 216                27                39               -3               59
# 217                27                39                0               64
# 218                28                40                0               68
# 219                28                40               -6               70
# 220                28                40               -4               68
# 221                28                40                1               54
# 222                28                40               -7               61
# 223                28                40              -15               63
# 224                28                41               -6               61
# 225                28                41               -2               65
# 226                28                41               -3               62
# 227                29                41               -1               64
# 228                29                41                2               63
# 229                29                42               -8               73
# 230                29                42                1               71
# 231                29                42               -5               67
# 232                29                42                0               68
# 233                30                42                1               66
# 234                30                43                2               69
# 235                30                43                4               68
# 236                30                43                8               69
# 237                30                43                5               70
# 238                30                44               -4               75
# 239                31                44                1               75
# 240                31                44                7               65
# 241                31                44                5               72
# 242                31                45                5               67
#
#      record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 215                  1920                  1989                  0.03
# 216                  1881                  1988                  1.02
# 217                  1955                  1991                  0.00
# 218                  1918                  1991                  0.00
# 219                  1918                  1991                  0.00
# 220                  1895                  2008                  0.00
# 221                  1910                  1938                  0.02
# 222                  1934                  1965                  0.00
# 223                  1934                  1990                  0.09
# 224                  1899                  2001                  0.01
# 225                  1899                  1960                  0.00
# 226                  1914                  1999                  0.00
# 227                  1914                  1951                  0.00
# 228                  1916                  1946                  0.02
# 229                  1943                  1949                  0.00
# 230                  1888                  1954                  0.00
# 231                  1896                  1976                  0.14
# 232                  1979                  1981                  0.00
# 233                  1936                  1997                  0.00
# 234                  2015                  1939                  0.00
# 235                  1896                  1930                  0.61
# 236                  1963                  1997                  0.10
# 237                  1889                  1985                  0.00
# 238                  1873                  1985                  0.00
# 239                  1914                  1930                  0.00
# 240                  1990                  1890                  0.00
# 241                  1900                  1997                  0.00
# 242                  1934                  1976                  0.00
#
#      average_precipitation  record_precipitation  precipitated  is_hot
# 215                   0.11                  2.12             1       0
# 216                   0.11                  2.98             1       0
# 217                   0.11                  1.55             0       0
# 218                   0.10                  2.10             0       0
# 219                   0.11                  1.43             0       0
# 220                   0.11                  2.74             0       0
# 221                   0.11                  2.96             1       0
# 222                   0.11                  1.15             0       0
# 223                   0.10                  1.74             1       0
# 224                   0.11                  2.63             1       0
# 225                   0.10                  2.74             0       0
# 226                   0.11                  1.66             0       0
# 227                   0.10                  2.42             0       0
# 228                   0.11                  1.59             1       0
# 229                   0.10                  1.73             0       0
# 230                   0.12                  1.40             0       0
# 231                   0.11                  1.49             1       0
# 232                   0.11                  1.50             0       0
# 233                   0.11                  2.15             0       0
# 234                   0.11                  3.07             0       0
# 235                   0.11                  1.86             1       0
# 236                   0.11                  2.39             1       0
# 237                   0.12                  1.38             0       0
# 238                   0.12                  1.69             0       0
# 239                   0.11                  2.11             0       0
# 240                   0.12                  1.87             0       0
# 241                   0.12                  1.56             0       0
# 242                   0.12                  1.21             0       0

# %% [markdown]
# Store this new DataFrame with only the February rows in a new variable, and then create a histogram of the distribution of the minimum daily temperatures in February 2015.

# %%
febraury_data = weather[feb_filter].reset_index().drop(columns=["index"])

# %%
febraury_data.head(1)
# Out:
#         date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0 2015-02-01                28               20               36
#
#    average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                27                39               -2               67
#
#    record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                  1920                  1989                  0.03
#
#    average_precipitation  record_precipitation  precipitated  is_hot
# 0                   0.11                  2.12             1       0

# %%
feb_counts = febraury_data["actual_min_temp"].value_counts()
feb_counts.plot(kind = "bar")
plt.title("Breakdown of minimum daily temperature (Feb. 2015)")
plt.xlabel("Minimum daily temperature (F)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# See https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#time-date-components for the different properties that can be used after dt.  For example to get the mean of the historical average precipitation for all Tuesdays:

# %%
tues_filter = weather["date"].dt.dayofweek == 1
tues_weather = weather[tues_filter]
tues_weather["average_precipitation"].mean()
# Out:
# 0.1364150943396227

# %% [markdown]
# Can you compute the standard deviation (`.std()`) of the record maximum temperature in the first quarter?

# %%
# Assuming January 1st to March 31st as Q1 2015
q1_data = weather[(weather['date'] >= '2015-01-01') & (weather['date'] <= '2015-03-31')]

# Calculate the std
q1_max_temp_std = q1_data['actual_max_temp'].std()

# Print output
print(f"Standard Deviation of the record max. temp. in Q1 2015: {q1_max_temp_std}")
# Out:
# Standard Deviation of the record max. temp. in Q1 2015: 9.312309118773683

# %% [markdown]
# Reference for functions seen in MAT 128 that compute measures of center and spread of a column:
# * `.mean()` - computes the mean
# * `.median()` - computes the median
# * `.mode()` - computes the mode
# * `.var()` - computes the variance
# * `.std()` - computes the standard deviation
# * `.min()` - finds the minimum value in the column
# * `.max()` - finds the maximum value in the column
# * `.idxmin()` - find the row number containing the minimum value in the column
# * `.idxmax()` - find the row number containing the maximum value in the column

# %% [markdown]
# #### Optional challenge questions:
# * Create a bar chart of the number of record maximum temperatures that occured in the year 2000 or later and the number that occured before 2000
# * There is an English proverb that "March comes in like a lion and out like a lamb".  Is the mean temperature (or precipitation) at the beginning of March significantly lower (or higher) than at the end of March?
# * What would you like to know about the NYC weather in this data set?  Plot or compute it.
